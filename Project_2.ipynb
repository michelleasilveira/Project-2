# %% [markdown]
# <a href="https://colab.research.google.com/github/michelleasilveira/Project-2/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating the Class

# %%
# %%writefile SparkDataCheck.py
# Creating Python code from colab
# Out:
# Overwriting SparkDataCheck.py
